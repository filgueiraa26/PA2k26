# %% [markdown]
# <a href="https://colab.research.google.com/github/filgueiraa26/PA2k26/blob/main/Aula04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Aula de programação e algoritimos
#
# * Calcular uma área
#
# # Entrada
#
# Ler lado1
# Ler lado2
#
# #Processamento
#
# area = lado1 * lado2
#
# #Saída
#
# Escrever o total da area

# %%
# Variáveis que recebe o valor dos lados

#Entrada
lado_1 = 7
lado_2 = 3

# %%
# Processamento

area = lado_1 * lado_2

# %%
# Saída

print (f"Total da área calculada: {area} metros quadrados")
# Out:
# Total da área calculada: 21 metros quadrados

# %% [markdown]
# Operadores aritméticos
#
#
# 1.    Soma = +
# 2.    Subtração = -
# 3.    Multiplicação = *
# 4.    Divisão = /

# %% [markdown]
# Atividade:
#
# Fazer um algoritimo e depois o programa que recebe 4 notas do aluno e calcula a média aritmética e imprimir a média.

# %%
# Variáveis que recebem a notas

 #Entrada
nota1 = 8
nota2 = 9
nota3 = 6
nota4 = 4

# %%
# Processamento
media_aritmetica = (nota1 + nota2 + nota3 + nota4) / 4

# %%
# Saída

print (media_aritmetica)
# Out:
# 6.75

# %% [markdown]
# Faça um algoritimo que receba um número e calcule o dobro desse número

# %%
# Variávies que recebem e calculam o número

# Entrada
numero = 5

# %%
# Processamento

valor = numero*2

# %%
# Saída
print (f" valor duplicado : {valor}")
# Out:
#  valor duplicado : 10
